# %% [markdown]
# ### Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mobilenet_preprocess
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set Dataset Path

# %%
train_dir = r"E:\A\OneDrive\Documents\3rd year\5th SEM Materials of SR.Mishra(3rd yr)\Deep Learning for Image Analytics\Project\Groundnut_Leaf_dataset\Main Used Dataset"

img_size = (224, 224)
batch_size = 32

# %% [markdown]
# ### Data Preprocessing

# %%
datagen = ImageDataGenerator(
    preprocessing_function=mobilenet_preprocess,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

num_classes = len(train_gen.class_indices)
# Out:
# Found 6329 images belonging to 6 classes.
# Found 1581 images belonging to 6 classes.

# %% [markdown]
# ### Helper Function for Model Building

# %%
def build_model(base_model, preprocess_func):
    base_model.trainable = False
    model = Sequential([
        tf.keras.layers.InputLayer(input_shape=(224,224,3)),
        tf.keras.layers.Lambda(preprocess_func),
        base_model,
        GlobalAveragePooling2D(),
        Dense(64, activation="relu"),
        Dropout(0.3),
        Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer=Adam(1e-4),
                  loss="categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# %% [markdown]
# ### Train with MobileNetV2

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

mobilenet_base = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224,224,3))

mobilenet_base.trainable = True
for layer in mobilenet_base.layers[:-40]:
    layer.trainable = False

mobilenet_model = build_model(mobilenet_base, mobilenet_preprocess)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-6, verbose=1)

history_mobilenet = mobilenet_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=30,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# WARNING:tensorflow:From C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 183s 890ms/step - accuracy: 0.1940 - loss: 1.8450 - val_accuracy: 0.2581 - val_loss: 1.7664 - learning_rate: 1.0000e-04
# Epoch 2/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 183s 927ms/step - accuracy: 0.2768 - loss: 1.7141 - val_accuracy: 0.2663 - val_loss: 1.7393 - learning_rate: 1.0000e-04
# Epoch 3/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 105s 528ms/step - accuracy: 0.3106 - loss: 1.6631 - val_accuracy: 0.2808 - val_loss: 1.7129 - learning_rate: 1.0000e-04
# Epoch 4/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 484ms/step - accuracy: 0.3399 - loss: 1.6213 - val_accuracy: 0.3099 - val_loss: 1.6870 - learning_rate: 1.0000e-04
# Epoch 5/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 97s 492ms/step - accuracy: 0.3535 - loss: 1.5878 - val_accuracy: 0.3112 - val_loss: 1.6669 - learning_rate: 1.0000e-04
# Epoch 6/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 100s 505ms/step - accuracy: 0.3639 - loss: 1.5572 - val_accuracy: 0.3302 - val_loss: 1.6424 - learning_rate: 1.0000e-04
# Epoch 7/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 98s 494ms/step - accuracy: 0.3748 - loss: 1.5357 - val_accuracy: 0.3428 - val_loss: 1.6298 - learning_rate: 1.0000e-04
# Epoch 8/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 486ms/step - accuracy: 0.3869 - loss: 1.5098 - val_accuracy: 0.3365 - val_loss: 1.6120 - learning_rate: 1.0000e-04
# Epoch 9/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 97s 488ms/step - accuracy: 0.3873 - loss: 1.4939 - val_accuracy: 0.3365 - val_loss: 1.6050 - learning_rate: 1.0000e-04
# Epoch 10/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 97s 492ms/step - accuracy: 0.4046 - loss: 1.4751 - val_accuracy: 0.3567 - val_loss: 1.5844 - learning_rate: 1.0000e-04
# Epoch 11/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 484ms/step - accuracy: 0.4124 - loss: 1.4550 - val_accuracy: 0.3605 - val_loss: 1.5740 - learning_rate: 1.0000e-04
# Epoch 12/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 484ms/step - accuracy: 0.4162 - loss: 1.4398 - val_accuracy: 0.3624 - val_loss: 1.5631 - learning_rate: 1.0000e-04
# Epoch 13/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 97s 489ms/step - accuracy: 0.4253 - loss: 1.4279 - val_accuracy: 0.3593 - val_loss: 1.5601 - learning_rate: 1.0000e-04
# Epoch 14/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 100s 503ms/step - accuracy: 0.4337 - loss: 1.4146 - val_accuracy: 0.3637 - val_loss: 1.5447 - learning_rate: 1.0000e-04
# Epoch 15/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 98s 495ms/step - accuracy: 0.4312 - loss: 1.4026 - val_accuracy: 0.3688 - val_loss: 1.5341 - learning_rate: 1.0000e-04
# Epoch 16/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 99s 500ms/step - accuracy: 0.4377 - loss: 1.3899 - val_accuracy: 0.3776 - val_loss: 1.5264 - learning_rate: 1.0000e-04
# Epoch 17/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 98s 497ms/step - accuracy: 0.4445 - loss: 1.3761 - val_accuracy: 0.3612 - val_loss: 1.5210 - learning_rate: 1.0000e-04
# Epoch 18/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 98s 496ms/step - accuracy: 0.4459 - loss: 1.3709 - val_accuracy: 0.3833 - val_loss: 1.5056 - learning_rate: 1.0000e-04
# Epoch 19/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 98s 496ms/step - accuracy: 0.4615 - loss: 1.3541 - val_accuracy: 0.3814 - val_loss: 1.4939 - learning_rate: 1.0000e-04
# Epoch 20/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 487ms/step - accuracy: 0.4615 - loss: 1.3480 - val_accuracy: 0.3637 - val_loss: 1.5118 - learning_rate: 1.0000e-04
# Epoch 21/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 485ms/step - accuracy: 0.4596 - loss: 1.3476 - val_accuracy: 0.3922 - val_loss: 1.4899 - learning_rate: 1.0000e-04
# Epoch 22/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 98s 493ms/step - accuracy: 0.4660 - loss: 1.3314 - val_accuracy: 0.3865 - val_loss: 1.4837 - learning_rate: 1.0000e-04
# Epoch 23/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 103s 518ms/step - accuracy: 0.4667 - loss: 1.3285 - val_accuracy: 0.3820 - val_loss: 1.4869 - learning_rate: 1.0000e-04
# Epoch 24/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 99s 499ms/step - accuracy: 0.4761 - loss: 1.3175 - val_accuracy: 0.3966 - val_loss: 1.4741 - learning_rate: 1.0000e-04
# Epoch 25/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 97s 492ms/step - accuracy: 0.4757 - loss: 1.3110 - val_accuracy: 0.3997 - val_loss: 1.4663 - learning_rate: 1.0000e-04
# Epoch 26/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 486ms/step - accuracy: 0.4827 - loss: 1.2992 - val_accuracy: 0.4035 - val_loss: 1.4569 - learning_rate: 1.0000e-04
# Epoch 27/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 484ms/step - accuracy: 0.4889 - loss: 1.2874 - val_accuracy: 0.4295 - val_loss: 1.4575 - learning_rate: 1.0000e-04
# Epoch 28/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 99s 499ms/step - accuracy: 0.4838 - loss: 1.2900 - val_accuracy: 0.3985 - val_loss: 1.4593 - learning_rate: 1.0000e-04
# Epoch 29/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 484ms/step - accuracy: 0.4852 - loss: 1.2803 - val_accuracy: 0.4023 - val_loss: 1.4458 - learning_rate: 1.0000e-04
# Epoch 30/30
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 96s 484ms/step - accuracy: 0.4903 - loss: 1.2729 - val_accuracy: 0.4086 - val_loss: 1.4466 - learning_rate: 1.0000e-04

# %% [markdown]
# ### Evaluation

# %%
print(" MobileNetV2 Accuracy:", mobilenet_model.evaluate(val_gen, verbose=0)[1])
# Out:
#  MobileNetV2 Accuracy: 0.40227705240249634

# %% [markdown]
# ### Results

# %%
plt.plot(history_mobilenet.history['val_accuracy'], label="MobileNetV2")
plt.title("Validation Accuracy Comparison")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ### Save the Best Model

# %%
# Example: if MobileNetV2 performed best
mobilenet_model.save("best_groundnut_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Visualize Training Results (Accuracy & Loss)

# %%
def plot_training(history, model_name):
    import matplotlib.pyplot as plt

    plt.figure(figsize=(10,4))
    
    # Accuracy
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.legend()
    
    # Loss
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{model_name} Loss')
    plt.legend()
    
    plt.show()

# ✅ Plot results for your MobileNetV2 model
plot_training(history_mobilenet, "MobileNetV2")

# %% [markdown]
# ### Evaluate on New Test Images

# %%
### Evaluate on New Test Images

from tensorflow.keras.preprocessing import image
import numpy as np

# Correct image path
img_path = r"E:\A\OneDrive\Documents\3rd year\5th SEM Materials of SR.Mishra(3rd yr)\Deep Learning for Image Analytics\Project\Groundnut_Leaf_dataset\Main Used Dataset\healthy_leaf_1\2.jpg"

# ✅ Load and preprocess the image with correct size (224x224)
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = mobilenet_preprocess(img_array)

# Predict
prediction = mobilenet_model.predict(img_array)
predicted_class = list(train_gen.class_indices.keys())[np.argmax(prediction)]

print("Predicted Disease:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted Disease: healthy_leaf_1
